# %% [markdown]
# # Import dataset and relevant libraries

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("drinking_water_potability.csv")

# %%
df.head(10)
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.05786     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.54173     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.71654     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.58385     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.50849     9.077200  404.041635    563.885482
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# # Exploring the dataset

# %% [markdown]
# ## Looking for missing values and outliers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
# ph                 2785 non-null float64
# Hardness           3276 non-null float64
# Solids             3276 non-null float64
# Chloramines        3276 non-null float64
# Sulfate            2495 non-null float64
# Conductivity       3276 non-null float64
# Organic_carbon     3276 non-null float64
# Trihalomethanes    3114 non-null float64
# Turbidity          3276 non-null float64
# Potability         3276 non-null int64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.isnull().sum()/len(df)
# Out:
# ph                 0.149878
# Hardness           0.000000
# Solids             0.000000
# Chloramines        0.000000
# Sulfate            0.238400
# Conductivity       0.000000
# Organic_carbon     0.000000
# Trihalomethanes    0.049451
# Turbidity          0.000000
# Potability         0.000000
# dtype: float64

# %% [markdown]
# - Pour Thrihalomethanes, moins de 5% des lignes sont manquantes. On pourrait drop ces lignes sans trop impacter notre dataset
# - Cependant pour PH et Sulfate il y a beaucoup trop de valeurs manquantes donc il faudra les remplacer. Soit vérifier si cela provient de la valeur d'une autre variable et l'utiliser pour remplacer les valeurs manquantes, soit utiliser la mediane ou la moyenne

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690300     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833605     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762125     8.114887   359.950170
# max      14.000000   323.124000  61227.196010    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
import seaborn as sns


corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
df[df.ph.isnull()]
# Out:
#       ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0    NaN  204.890456  20791.318980     7.300212  368.516441    564.308654
# 8    NaN  118.988579  14285.583850     7.804174  268.646941    389.375566
# 13   NaN  150.174923  27331.361960     6.838223  299.415781    379.761835
# 20   NaN  227.435048  22305.567410    10.333918         NaN    554.820087
# 22   NaN  215.977859  17107.224230     5.607060  326.943978    436.256194
# 27   NaN  145.768181  13224.935640     7.906445  304.001993    298.990667
# 28   NaN  266.421018  26362.965010     7.700063  395.389490    364.480107
# 29   NaN  148.153061  15193.413470     9.046833  307.011793    563.804743
# 34   NaN  232.280452  14787.206260     5.474915         NaN    383.981723
# 38   NaN  143.453731  19942.273220     5.890755         NaN    427.130672
# 40   NaN  233.858996  11703.923910     4.599388  309.039320    349.399632
# 48   NaN  129.890572  34415.853150     6.321929  304.535224    470.329168
# ...

# %% [markdown]
# - Regarding the PH as we can see there are no variables really correlated with the PH. We could do either replace the missing values by the mean or median, or we could do something a little bit more meaningful. We have the WHO recommendations regarding the PH of potable water. We could replace the missing values by these recommended values so it could make more sense regarding our use case.

# %%
df[df.Sulfate.isnull()]
# Out:
#             ph    Hardness        Solids  Chloramines  Sulfate  Conductivity  \
# 1     3.716080  129.422921  18630.057860     6.635246      NaN    592.885359
# 2     8.099124  224.236259  19909.541730     9.275884      NaN    418.606213
# 11    7.974522  218.693300  18767.656680     8.110385      NaN    364.098230
# 14    7.496232  205.344982  28388.004890     5.072558      NaN    444.645352
# 16    7.051786  211.049406  30980.600790    10.094796      NaN    315.141267
# 18    8.975464  279.357167  19460.398130     6.204321      NaN    431.443990
# 20         NaN  227.435048  22305.567410    10.333918      NaN    554.820087
# 23    3.902476  196.903247  21167.500100     6.996312      NaN    444.478882
# 31    9.825490  190.756618  19677.892470     6.757541      NaN    452.836235
# 34         NaN  232.280452  14787.206260     5.474915      NaN    383.981723
# 37    5.618064  304.235912  17281.975170     6.101084      NaN    399.471566
# ...

# %% [markdown]
# - Same thing as for the PH. There is no obvious correlated variable in the dataset with the SULFATE. Therefore, we could either replace the values by the mean or median, or we could replace it with recommendations by WHO so it makes more sense with our use case.

# %% [markdown]
# - Ultimately we can train our model on a dataset with the values filled with the mean(or median) and another model on a dataset filled with the WHO proposed values

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### PH

# %% [markdown]
# - Selon les recommandations de WHO il faut que le PH soit dans la limite de 6.5 et 8.5, on peut créer un feature PH_WHO qui vaut 0 si en dehors de ces valeurs et 1 sinon

# %%
df["PH_WHO"]=[int(df['ph'][i]<6.5 or df['ph'][i]>8.5 ) for i in range (0,len(df))]

# %% [markdown]
# ### Solids

# %% [markdown]
# - The WHO Recommendations are ideally max 500 and maaax really 1000

# %%
df["SOLIDS_WHO"]=[int(df['Solids'][i]>1000 ) for i in range (0,len(df))]

# %%
df["SOLIDS_WHO"].value_counts()
# Out:
# 1    3274
# 0       2
# Name: SOLIDS_WHO, dtype: int64

# %% [markdown]
# - On voit que problème ya seulement 2 instances qui entrent dans les recommandations. Peut être faudra drop ce feature qui sert pas à grand chose

# %% [markdown]
# ### Chloramines

# %% [markdown]
# - Reco WHO max 4 mg/l

# %%
df["CHLORAMINES_WHO"]=[int(df['Chloramines'][i]<4 ) for i in range (0,len(df))]

# %%
df["CHLORAMINES_WHO"].value_counts()
# Out:
# 0    3187
# 1      89
# Name: CHLORAMINES_WHO, dtype: int64

# %% [markdown]
# ### Sulfate

# %% [markdown]
# - WHO dis entre 3 et 30 mais ca arrive que ce soit jusqu'a 1000. On parle d'eau douce ici et pas forcement potable

# %%
df["SULFATE_WHO"]=[int(df['Sulfate'][i]<1000) for i in range (0,len(df))]

# %%
df["SULFATE_WHO"].value_counts()
# Out:
# 1    2495
# 0     781
# Name: SULFATE_WHO, dtype: int64

# %% [markdown]
# - Avec inférieur à 30 y en a aucun donc on met moins de 1000

# %% [markdown]
# ### Conductivity

# %% [markdown]
# - WHO dis max 400

# %%
df["CONDUCTIVITY_WHO"]=[int(df['Conductivity'][i]<400) for i in range (0,len(df))]

# %%
df["CONDUCTIVITY_WHO"].value_counts()
# Out:
# 0    1962
# 1    1314
# Name: CONDUCTIVITY_WHO, dtype: int64

# %% [markdown]
# ### Organic_carbon

# %% [markdown]
# - WHO dis en dessous de 2 et en dessous de 4 pour les sources qu'on traite pour qu'elle soit potable par la suite

# %%
df["ORGANIC_CARBON_WHO"]=[int(df['Organic_carbon'][i]<4) for i in range (0,len(df))]

# %%
df["ORGANIC_CARBON_WHO"].value_counts()
# Out:
# 0    3275
# 1       1
# Name: ORGANIC_CARBON_WHO, dtype: int64

# %% [markdown]
# Sert à rien y en a aucun qui suit cette valeur recommandée c'est bizarre

# %% [markdown]
# ### Trihalomethanes

# %% [markdown]
# - WHO recommande en dessous de 80

# %%
df["TRIHALOMETHANES_WHO"]=[int(df['Trihalomethanes'][i]<80) for i in range (0,len(df))]

# %%
df["TRIHALOMETHANES_WHO"].value_counts()
# Out:
# 1    2512
# 0     764
# Name: TRIHALOMETHANES_WHO, dtype: int64

# %% [markdown]
# ### Turbidity

# %% [markdown]
# - WHO recommande une valeur moyenne de 5

# %%
df["TURBIDITY_WHO"]=[int(df['Turbidity'][i]<4.8) for i in range (0,len(df))]

# %%
df["TURBIDITY_WHO"].value_counts()
# Out:
# 1    2797
# 0     479
# Name: TURBIDITY_WHO, dtype: int64

# %% [markdown]
# - J'ai pris 4.8 pour avoir un petit pourcentage de variation possible

# %% [markdown]
# ## Visualisations du jeu de données

# %%
sns.set_theme()
import matplotlib.pyplot as plt

# %%
# Analyse de la distribution des variables

for axis in df.columns: 
    if axis != 'Potability':
        sns.displot(df[axis], kde= True)
plt.show()

# %% [markdown]
# >- Toutes les variables continues semblent suivre une loi normale, et ne pas comporter de valeurs aberrantes. Elles semblent cependant présenter une faible corrélation avec la cible.

# %%
# Valeurs aberrrantes ? yessir

# %%
# askjdnajs
