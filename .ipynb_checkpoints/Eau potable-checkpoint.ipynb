# %% [markdown]
# <hr style="border-width:2px;border-color:#701f57">
# <center><h1> Évaluation de la potabilité de l'eau </h1></center>
# <hr style="border-width:2px;border-color:#701f57">
#
# ## 1. Introduction
#
# L'objectif de ce projet est de déterminer à partir d'un jeu de données si une eau est potable ou non.
# >
# > * Les normes imposées par l'OMS pour définir si l'eau est potable ou non sont les suivantes :
# >
# >> - **6.5 < pH < 8.5**
# >> - Desirable limit: **Solids < 500 mg/L** | Maximum limit: **Solids < 1000 mg/L**
# >> - **Chloramines < 4 mg/L** (= 4 ppm)
# >> - In seawater: **Sulfate ~ 2.7 mg/L** | In most fresh water supplies: **3 < Sulfate < 30 mg/L** | In some geographic locations: **Sulfate = 1000 mg/L**
# >> - **Conductivity < 400 µS/cm**
# >> - **Organic_carbon < 2 mg/L** in treated/drinking water | **Organic_carbon < 4 mg/L** in source water used for treatment
# >> - **Trihalomethanes < 80 ppm**
# >> - Recommended value: **Turbidity = 5.00 NTU**
#
#
#
# > * Importons toutes les bibliothèques nécessaires pour le projet

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
#from utils import process_remove_outliers_ph, process_remove_outliers_quartile
import os

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    make_scorer,
    precision_score,
    recall_score,
)
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
)
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    classification_report,
    confusion_matrix,
)

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, KernelPCA
from sklearn.preprocessing import scale

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Exploration des données
#
# ### Affichage et description du jeu de données

# %%
df = pd.read_csv("drinking_water_potability.csv")

df.head(15)
# Out:
#            ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0         NaN  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1    3.716080  129.422921  18630.05786     6.635246         NaN    592.885359
# 2    8.099124  224.236259  19909.54173     9.275884         NaN    418.606213
# 3    8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4    9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 5    5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 6   10.223862  248.071735  28749.71654     7.513408  393.663396    283.651634
# 7    8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
# 8         NaN  118.988579  14285.58385     7.804174  268.646941    389.375566
# 9   11.180284  227.231469  25484.50849     9.077200  404.041635    563.885482
# 10   7.360640  165.520797  32452.61441     7.550701  326.624354    425.383420
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690300     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833605     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762125     8.114887   359.950170
# max      14.000000   323.124000  61227.196010    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %% [markdown]
# ### Analyse des variables
#
# * Distribution des variables

# %%
#Affichage de boîtes à moustaches et histogrammes pour analyser les distributions de chacunes des features
# ainsi que pour identifier d'éventuelles valeurs aberrantes 

sns.set_theme() 
sns.set(palette = "rocket")

fig, ax = plt.subplots(len(df.columns), 2, figsize = (20, 20))
for i in range(len(df.columns)):
    y_not_potable=df[df.columns[i]].loc[df["Potability"]==0]
    y_potable=df[df.columns[i]].loc[df["Potability"]==1]
    sns.histplot(y_not_potable, ax = ax[i,1], kde=True, color="C4")
    sns.histplot(y_potable, ax = ax[i,1], kde=True, color="C2")
    sns.boxplot(y=df["Potability"], x=df[df.columns[i]], ax = ax[i,0], orient="h", palette={0: "C4", 1: "C2"})
plt.tight_layout()
plt.savefig('Univariate_analysis.png')
plt.show()

# %% [markdown]
# * Données manquantes

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
#En pourcentage

df.isnull().sum()/len(df)*100
# Out:
# ph                 14.987790
# Hardness            0.000000
# Solids              0.000000
# Chloramines         0.000000
# Sulfate            23.840049
# Conductivity        0.000000
# Organic_carbon      0.000000
# Trihalomethanes     4.945055
# Turbidity           0.000000
# Potability          0.000000
# dtype: float64

# %% [markdown]
# * Seules les variables pH, Sulfate, et Trihalométhanes contiennent des données manquantes. Cependant, ces données sont manquantes en trop grande proportion pour être supprimées. Il faudra donc remplir ces cases, avec la moyenne par exemple, ou selon d'autres méthodes si l'on note une éventuelle corrélation entre les variables.
#
# ### Analyse de Corrélation entre les variables
#
# * Matrice de corrélation

# %%
plt.figure(figsize=(12,8))

corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True, annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)

plt.savefig('Correlation_matrix.png')
plt.show()

# %% [markdown]
# * Analyse 'spatiale' de distribution de la target par feature, sous la forme d'un pairplot

# %%
plt.figure(figsize=(22,22))
sns.pairplot(df,hue="Potability", diag_kind='kde',  markers=".", palette={0: "C2", 1: "C4"})
plt.savefig('pairplots.png')
plt.show()

# %% [markdown]
# ## 3. Preprocessing des données
#
# ### Gestion des données aberrantes
#
# Lors de l'exploration du jeu de données, nous avons remarqué la présence de valeurs "aberrantes" concernant les données relevées d'eau potable (`potability = 1`). Nous allons supprimer ces outliers avec la méthode IQR, et analyser le nombre de lignes supprimées.

# %%
df_train,df_test=train_test_split(df,train_size=0.8,random_state=0,stratify=df['Potability'])

train_proportion_potable = df_train.Potability[df_train['Potability']==1].value_counts()/df_train.shape[0]
train_proportion_notpotable = df_train.Potability[df_train['Potability']==0].value_counts()/df_train.shape[0]

test_proportion_potable = df_test.Potability[df_test['Potability']==1].value_counts()/df_test.shape[0]
test_proportion_notpotable = df_test.Potability[df_test['Potability']==0].value_counts()/df_test.shape[0]

print(f"Proportions de la target Potability dans le train set :\n Potable: {train_proportion_potable[1]}, \n Non Potable: {train_proportion_notpotable[0]}")

print(f"Proportions de la target Potability dans le test set :\n Potable: {test_proportion_potable[1]}, \n Non Potable: {test_proportion_notpotable[0]}")
# Out:
# Proportions de la target Potability dans le train set :
#  Potable: 0.3900763358778626,
#  Non Potable: 0.6099236641221374
# Proportions de la target Potability dans le test set :
#  Potable: 0.3902439024390244,
#  Non Potable: 0.6097560975609756

# %%
##Definition de la fonction pour drop les data points qui s'écartent de 1.5*IQR sur chaque feature
def remove_outliers_IQR(df):
    df_copy=df.copy()
    for feature in df.columns:
        Q25,Q75=df[feature].quantile(0.25),df[feature].quantile(0.75)
        cutoff=(Q75-Q25)*1.5
        lower, upper = Q25 - cutoff, Q75 + cutoff
        indexes_to_drop=df_copy[(df_copy[feature] <= lower) | (df_copy[feature] >= upper)].index
        df_copy = df_copy.drop(indexes_to_drop)
    return df_copy
        
train_outliers_removed=remove_outliers_IQR(df_train)
test_outliers_removed=remove_outliers_IQR(df_test)

print(f"En pourcentage, le nombre de lignes supprimées par l'IQR dans le train est de : "+ str(100*round(((train_outliers_removed.shape[0]-df_train.shape[0])/df_train.shape[0]),2))+"%")
print(f"En pourcentage, le nombre de lignes supprimées par l'IQR dans le test est de : "+ str(100*round(((test_outliers_removed.shape[0]-df_test.shape[0])/df_test.shape[0]),2))+"%")
# Out:
# En pourcentage, le nombre de lignes supprimées par l'IQR dans le train est de : -10.0%
# En pourcentage, le nombre de lignes supprimées par l'IQR dans le test est de : -12.0%

# %%
# Suppression des outliers 

df_train=train_outliers_removed
df_val=test_outliers_removed #df_val sera utilisé pour la validation dans la partie Résultats

# %% [markdown]
# ## Réduction de dimension
#
# ### PCA

# %%
df_pca=pd.concat([df_train,df_test])
X = df_pca.iloc[:, :-1]
y = df_pca.iloc[:, -1]
# Pour effectuer une PCA, il faut scaler les features et remplacer les données manquantes donc on va effectuer
#un remplacement par la moyenne et un scaling standard pour cette partie sur les features
imputer=SimpleImputer(strategy="mean")
X=imputer.fit_transform(scale(X))

# %%
pca = PCA()
X_reduced = pca.fit_transform(scale(X))
pd.DataFrame(pca.components_.T).loc[:4,:5]
# Out:
#           0         1         2         3         4         5
# 0  0.385644  0.515341  0.152902 -0.060572  0.155369  0.005071
# 1  0.121365  0.600899 -0.380413 -0.149201 -0.022131  0.243676
# 2 -0.663373  0.041475  0.131276  0.102758 -0.204628 -0.073212
# 3  0.230659 -0.401898 -0.323512  0.141728 -0.247657  0.463302
# 4  0.526379 -0.387353  0.231752 -0.211104 -0.026238 -0.199565

# %%
pca = PCA(n_components = 2)
data_2D = pca.fit_transform(X)

fig = plt.figure()

ax = fig.add_subplot(111)
ax.scatter(data_2D[:, 0], data_2D[:, 1], c = y, cmap=plt.cm.Spectral)

ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')

ax.set_title("Données projetées sur les 2 axes de PCA")
plt.savefig('PCA.png')
plt.show()

print("La part de variance expliquée est", round(pca.explained_variance_ratio_.sum(),2))
# Out:
# La part de variance expliquée est 0.26

# %%
pca = PCA()
pca.fit(X)

plt.figure()
plt.xlim(0,10)
plt.plot(pca.explained_variance_ratio_);

plt.figure()
plt.xlim(0,10)
plt.axhline(y = 0.9, color ='r', linestyle = '--')
plt.plot(pca.explained_variance_ratio_.cumsum())
plt.savefig('PCA2.png')
plt.show()

# %% [markdown]
# La part de variance expliquée dépasse les 90% avec les 7 premières composantes principales de la PCA.

# %% [markdown]
# ### TSNE

# %%
tsne = TSNE(n_components=2, method = 'barnes_hut')
dataTSNE = tsne.fit_transform(X)
fig = plt.figure()

ax = fig.add_subplot(111)
ax.scatter(dataTSNE[:, 0], dataTSNE[:, 1],  c = y, cmap=plt.cm.Spectral, alpha = .7, s = 4)

ax.set_title("Données projetées sur les 2 axes de Tsne")
plt.savefig('TSNE.png')
plt.show()

# %% [markdown]
# ### Gestion des données manquantes et normalisation
#
# Définissons une pipeline pour cette étape de preprocessing :
#
# > * Comme dit lors de l'exploration du dataset, il y a trop de cases vides pour que celles-ci soient supprimées. Nous avons remarqué une faible corrélation entre les variables du jeu de données, et estimons ainsi que remplir les cases vides avec des données multivariées (ex : **`Multivariate Imputer`** n'est pas pertinent. Nous nous contenterons donc de remplir chaque case vide par la moyenne de sa colonne avec le transformeur **`SimpleImputer`de `Scikit-learn`**.
# >
# >
# > * On observe sur les distributions en histogramme que les variables du jeu de données suivent une loi normale. On choisira par conséquent un **`StandardScaler()`** pour la normalisation des données.

# %%
#Définition de la pipeline 

preprocessing_pipe = Pipeline([
    ('missing', SimpleImputer(strategy="mean")),
    ('std_scaler', StandardScaler())])
X_train = df_train.drop('Potability', axis = 1)
y_train = df_train['Potability']
X_test = df_train.drop('Potability', axis = 1)
y_test = df_train['Potability']

preprocessing_pipe = preprocessing_pipe.fit(X_train,y_train)

# %% [markdown]
# ## 3. Modélisation
#
# Dans cette partie, nous allons entraîner plusieurs modèles de base, que nous allons comparer selon des métriques de base afin de n'en sélectionner que 2, dont les paramètres seront par la suite tunés, notamment par **`Nested cross-validation`**.

# %%
models, metrics = [
    LogisticRegression(class_weight = 'balanced'),
    SVC(class_weight = 'balanced'),
    KNeighborsClassifier(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
] , [accuracy_score, f1_score, precision_score, recall_score]

results = []

for model in models:
    scores = {"name": model.__class__.__name__}
    model = Pipeline([("preprocessing", preprocessing_pipe), ("model", model)])
    scores = {
            **scores,
            **{               
                metric.__name__: np.mean(
                    cross_val_score(
                        model, X_train, y_train, cv=5, scoring=make_scorer(metric)
                    )
                )
                for metric in metrics
            },
        }
    results.append(scores)

# %%
perfs = pd.DataFrame(results).sort_values(by = 'accuracy_score', ascending = False)

# %%
perfs
# Out:
#                          name  accuracy_score  f1_score  precision_score  \
# 3      RandomForestClassifier        0.659062  0.390048         0.627284
# 5  GradientBoostingClassifier        0.642584  0.326215         0.582440
# 1                         SVC        0.635844  0.539515         0.521508
# 2        KNeighborsClassifier        0.617237  0.406883         0.498091
# 4          AdaBoostClassifier        0.607520  0.284438         0.468419
# 0          LogisticRegression        0.504857  0.434505         0.384973
#
#    recall_score
# 3      0.313401
# 5      0.225918
# 1      0.559343
# 2      0.344426
# 4      0.205936
# 0      0.499368

# %%
plt.figure(figsize = (10,5))

sns.barplot(x="accuracy_score", y="name", data=perfs ,
             color="#701f57")

plt.yticks(fontsize = 10)
plt.xlabel('Score', fontsize = 14)
plt.ylabel('Modèle', fontsize = 14)
plt.title('Classement des modèles par accuracy_score', fontsize = 17);

# %% [markdown]
# Avec ce premier run, nous allons sélectionner les deux modèles suivants RandomForest et SVM pour réaliser donc le tuning de leur hyperparamètres et sélectionner le meilleur modèle.

# %% [markdown]
# ### Selection du modèle: Nested Cross Validation

# %%
#preprocessing X_Train & X_Test
X_train_p = preprocessing_pipe.transform(X_train)
X_test_p = preprocessing_pipe.transform(X_test)
#Définition des modèles à étudier 
clf_rf  = RandomForestClassifier(random_state=22)
clf_svc = SVC(random_state=22)

# %%
## Instanciation de paramètres pour Nested Cross-Validation

param_grid_rf  = [{'n_estimators': [10, 50, 100, 250, 500, 1000],
                   "max_depth": [None, 5, 10, 20, 30, 40],
                   'max_features': ['sqrt', 'log2']}]

param_grid_svc = [{'kernel': ['rbf', 'linear'],
                   "C": [0.1, 5, 10, 20, 50],
                    'gamma': np.logspace(-4, 0, 4)}]

gridcvs = {}

for pgrid, clf, name in zip((param_grid_rf, param_grid_svc),
                            (clf_rf, clf_svc),
                            ('RF', 'SVM')):

    gcv = GridSearchCV(clf,
                       pgrid,
                       cv=3,
                       refit=True)
    gridcvs[name] = gcv

# %%
gridcvs.items()
# Out:
# dict_items([('RF', GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=22),
#              param_grid=[{'max_depth': [None, 5, 10, 20, 30, 40],
#                           'max_features': ['sqrt', 'log2'],
#                           'n_estimators': [10, 50, 100, 250, 500, 1000]}])), ('SVM', GridSearchCV(cv=3, estimator=SVC(random_state=22),
#              param_grid=[{'C': [0.1, 5, 10, 20, 50],
#                           'gamma': array([1.00000000e-04, 2.15443469e-03, 4.64158883e-02, 1.00000000e+00]),
#                           'kernel': ['rbf', 'linear']}]))])

# %%
## Evalutation des scores de Cross-validation imbriquée

outer_cv = StratifiedKFold(n_splits=3, shuffle=True)
outer_scores = {}

for name, gs in gridcvs.items():
    nested_score = cross_val_score(gs, 
                                   X_train_p, 
                                   y_train, 
                                   cv=outer_cv)
    outer_scores[name] = nested_score
    print(f'{name}: outer accuracy {100*nested_score.mean():.2f} +/- {100*nested_score.std():.2f}')
# Out:
# RF: outer accuracy 65.02 +/- 0.54
# SVM: outer accuracy 66.33 +/- 0.42

# %% [markdown]
# Cette cross-validation imbriquée nous montre que **`Random Forest` et `SVM`** nous permettent d'avoir des performances similaires. **`SVM`** fournit cependant la **variance la plus faible** sur la nested cross validation. Nous entrainerons les deux modèles et analyserons leurs performances sur la fin.
#
# Il convient de noter que, souvent, le score moyen obtenu par `nested cross-validation` sur l'ensemble d'entraînement peut s'avérer être une estimation pessimiste du modèle, car non entraîné sur la totalité des données à disposition. Ainsi, il est possible d'obtenir de meilleures perfs à l'entrainement final.
#
#
#
# ### Modèles final et analyse des performances
#
# * Entraînement du modèle **`SVM`**

# %%
from sklearn.metrics import accuracy_score

final_clf = gridcvs['SVM']
final_clf.fit(X_train_p, y_train)

print(f'Best Parameters: {final_clf.best_params_}')

train_acc = accuracy_score(y_true=y_train, y_pred=final_clf.predict(X_train_p))
test_acc = accuracy_score(y_true=y_test, y_pred=final_clf.predict(X_test_p))

print(f'Training Accuracy: {100*train_acc:.2f}')
print(f'Test Accuracy: {100*test_acc:.2f}')
# Out:
# Best Parameters: {'C': 20, 'gamma': 0.046415888336127774, 'kernel': 'rbf'}
# Training Accuracy: 75.79
# Test Accuracy: 75.79

# %% [markdown]
# * Rapport de classification **`SVM`**

# %%
y_pred = final_clf.predict(X_test_p)

print(classification_report(y_train, y_pred))

fig,ax = plt.subplots(figsize=(35,5));
ConfusionMatrixDisplay(confusion_matrix(y_train, y_pred, normalize="pred")).plot(cmap='rocket', ax=ax);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.94      0.83      1464
#            1       0.83      0.46      0.59       903
#
#     accuracy                           0.76      2367
#    macro avg       0.78      0.70      0.71      2367
# weighted avg       0.77      0.76      0.74      2367

# %% [markdown]
# * Entrainement du modèle final **`Random forest`**

# %%
final_rf = gridcvs['RF']
final_rf.fit(X_train_p, y_train)

print(f'Best Parameters: {final_rf.best_params_}')

train_acc = accuracy_score(y_true=y_train, y_pred=final_rf.predict(X_train_p))
test_acc = accuracy_score(y_true=y_test, y_pred=final_rf.predict(X_test_p))

print(f'Training Accuracy: {100*train_acc:.2f}')
print(f'Test Accuracy: {100*test_acc:.2f}')
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 1000}
# Training Accuracy: 83.86
# Test Accuracy: 83.86

# %% [markdown]
# * Performances du **`Random Forest`** final

# %%
y_pred = final_rf.predict(X_test_p)

print(classification_report(y_train, y_pred))

fig,ax = plt.subplots(figsize=(35,5));
ConfusionMatrixDisplay(confusion_matrix(y_train, y_pred, normalize="pred")).plot(cmap='rocket', ax=ax);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      1464
#            1       1.00      0.58      0.73       903
#
#     accuracy                           0.84      2367
#    macro avg       0.90      0.79      0.81      2367
# weighted avg       0.87      0.84      0.83      2367

# %% [markdown]
# * Interpétabilité du **`Random Forest`**

# %%
#FEATURE IMPORTANCE 

importances = final_rf.best_estimator_.feature_importances_
rf_importances = pd.Series(importances, index= list(X_train.columns))

fig, ax = plt.subplots()
rf_importances.plot.bar( ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
importances
# Out:
# array([0.15083509, 0.1203903 , 0.11168237, 0.11026571, 0.15975575,
#        0.08907138, 0.09001484, 0.0840814 , 0.08390317])

# %% [markdown]
# ### Explorations complémentaires

# %%
def BoundaryLine(kernel, algo, algo_name):
    reduction = KernelPCA(n_components=2, kernel = kernel)
    x_train_reduced = reduction.fit_transform(X_train)
    y_test_reduced = reduction.transform(x_test)
    
    classifier = algo
    classifier.fit(x_train_reduced, y_train)
    
    y_pred = classifier.predict(x_test_reduced)
    
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    
    plt.subplot(2,1,1)
    #Train set boundary
    X_set, y_set = x_train_reduced, y_train
    X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                         np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
    plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
                 alpha = 0.6, cmap = ListedColormap(('red', 'green')))
    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                    c = ListedColormap(('red', 'green'))(i), label = j)
    plt.title('{} Boundary Line with {} PCA (Train Set)' .format(algo_name, kernel))
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend()
    
    
    plt.subplot(2,1,2)
    #Test set boundary
    X_set, y_set = x_test_reduced, y_test
    X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                         np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
    plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
                 alpha = 0.6, cmap = ListedColormap(('red', 'green')))
    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                    c = ListedColormap(('red', 'green'))(i), label = j)
    plt.title('{} Boundary Line with {} PCA (Test Set)' .format(algo_name, kernel))
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend()
    plt.tight_layout()

# %%
for kernel in ['linear', 'poly', 'rbf', 'sigmoid', 'cosine']:
    reduction = KernelPCA(n_components=7, kernel = kernel)
    x_train_reduced = reduction.fit_transform(preprocessing_pipe.fit_transform(X_train))
    x_test_reduced = reduction.transform(preprocessing_pipe.fit_transform(X_test))
    
    classifier = final_clf
    classifier.fit(x_train_reduced, y_train)
    y_pred = classifier.predict(x_test_reduced)
    print("Classification report for "+str(kernel))
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# Classification report for linear
# [[1424   40]
#  [ 732  171]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.97      0.79      1464
#            1       0.81      0.19      0.31       903
#
#     accuracy                           0.67      2367
#    macro avg       0.74      0.58      0.55      2367
# weighted avg       0.72      0.67      0.60      2367
#
# Classification report for poly
# [[1425   39]
#  [ 756  147]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.97      0.78      1464
#            1       0.79      0.16      0.27       903
#
#     accuracy                           0.66      2367
#    macro avg       0.72      0.57      0.53      2367
# weighted avg       0.71      0.66      0.59      2367
#
# Classification report for rbf
# [[1464    0]
#  [ 903    0]]
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76      1464
# ...
